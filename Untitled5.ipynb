# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('intern.csv')
df
# Out:
#      ProductID       ProductName     Category   Price  Rating  NumReviews  \
# 0            1        Headphones  Electronics  400.31     1.7        3772
# 1            2        Headphones  Electronics  235.03     2.3        2919
# 2            3        Smartwatch  Electronics  417.90     1.8        1184
# 3            4        Smartphone  Electronics  152.70     3.4        2047
# 4            5            Laptop  Electronics  394.74     1.8        1267
# ..         ...               ...          ...     ...     ...         ...
# 995        996     Throw Blanket     Blankets  207.72     2.3        1973
# 996        997    Fleece Blanket     Blankets  268.60     3.2         841
# 997        998     Throw Blanket     Blankets   92.74     2.8        3454
# 998        999  Weighted Blanket     Blankets  152.28     1.3        2850
# 999       1000     Throw Blanket     Blankets  136.53     2.0        4055
#
#      StockQuantity  Discount  Sales   DateAdded
# ...

# %%
df.head(5)
# Out:
#    ProductID ProductName     Category   Price  Rating  NumReviews  \
# 0          1  Headphones  Electronics  400.31     1.7        3772
# 1          2  Headphones  Electronics  235.03     2.3        2919
# 2          3  Smartwatch  Electronics  417.90     1.8        1184
# 3          4  Smartphone  Electronics  152.70     3.4        2047
# 4          5      Laptop  Electronics  394.74     1.8        1267
#
#    StockQuantity  Discount  Sales   DateAdded
# 0             20      0.08    466  08-11-2023
# 1            663      0.33   1332  26-09-2023
# 2            459      0.31    252  18-10-2023
# 3            475      0.49   1806  03-12-2023
# 4            831      0.23   1508  08-08-2023

# %%
df.tail(5)
# Out:
#      ProductID       ProductName  Category   Price  Rating  NumReviews  \
# 995        996     Throw Blanket  Blankets  207.72     2.3        1973
# 996        997    Fleece Blanket  Blankets  268.60     3.2         841
# 997        998     Throw Blanket  Blankets   92.74     2.8        3454
# 998        999  Weighted Blanket  Blankets  152.28     1.3        2850
# 999       1000     Throw Blanket  Blankets  136.53     2.0        4055
#
#      StockQuantity  Discount  Sales   DateAdded
# 995             16      0.46    325  11-02-2024
# 996            201      0.39   1546  29-06-2023
# 997            880      0.02   1295  27-10-2023
# 998            752      0.34   1962  26-10-2023
# 999            282      0.38   1089  25-01-2024

# %%
#Handling the Data
#1.DEtecting Duplicatates and removing duplicates
#2.Detecting null values and filling/replacing/renaming null values
x=df.duplicated().sum()
x
# Out:
# 0

# %%
df[df.isna()].sum()
#There is no duplicates and null values in these data set so we can proceed with further --"Data analysis"
# Out:
# ProductID        0.0
# ProductName        0
# Category           0
# Price            0.0
# Rating           0.0
# NumReviews       0.0
# StockQuantity    0.0
# Discount         0.0
# Sales            0.0
# DateAdded          0
# dtype: object

# %%
#Get an overview using descriptive statistics (mean, median, mode, etc.).
#MEAN OF THE DATA OF ELECRONICS
print("The average price in the above electronics data =",df['Price'].mean())
print("The average ratings in the above electronics data =",df['Rating'].mean())
print("The average NumReviews in the above electronics data =",df['NumReviews'].mean())
print("The average StockQuantity in the above electronics data =",df['StockQuantity'].mean())
print("The average Discount in the above electronics data =",df['Discount'].mean())
print("The average Sales in the above electronics data =",df['Sales'].mean())
# Out:
# The average price in the above electronics data = 253.77551
# The average ratings in the above electronics data = 3.0256000000000003
# The average NumReviews in the above electronics data = 2498.753
# The average StockQuantity in the above electronics data = 495.395
# The average Discount in the above electronics data = 0.25164
# The average Sales in the above electronics data = 1011.037

# %%
#MEDAIN FOR ALL OF THE ABOVE CATERGORIES
print("The median price in the above electronics data =",df['Price'].median())
print("The median ratings in the above electronics data =",df['Rating'].median())
print("The median NumReviews in the above electronics data =",df['NumReviews'].median())
print("The median StockQuantity in the above electronics data =",df['StockQuantity'].median())
print("The median Discount in the above electronics data =",df['Discount'].median())
print("The median Sales in the above electronics data =",df['Sales'].median())
# Out:
# The median price in the above electronics data = 251.31
# The median ratings in the above electronics data = 3.1
# The median NumReviews in the above electronics data = 2476.0
# The median StockQuantity in the above electronics data = 505.0
# The median Discount in the above electronics data = 0.25
# The median Sales in the above electronics data = 998.0

# %%
#DESCRIPTIVE STASTICS
df.describe()
# Out:
#          ProductID       Price       Rating   NumReviews  StockQuantity  \
# count  1000.000000  1000.00000  1000.000000  1000.000000    1000.000000
# mean    500.500000   253.77551     3.025600  2498.753000     495.395000
# std     288.819436   141.40362     1.151004  1463.241871     292.799253
# min       1.000000    10.11000     1.000000     3.000000       0.000000
# 25%     250.750000   133.09250     2.100000  1201.750000     241.750000
# 50%     500.500000   251.31000     3.100000  2476.000000     505.000000
# 75%     750.250000   375.82750     4.000000  3797.500000     743.500000
# max    1000.000000   499.74000     5.000000  4994.000000     993.000000
#
#           Discount        Sales
# count  1000.000000  1000.000000
# mean      0.251640  1011.037000
# std       0.146455   582.113466
# min       0.000000     0.000000
# 25%       0.130000   502.000000
# 50%       0.250000   998.000000
# 75%       0.380000  1540.000000
# max       0.500000  1997.000000

# %%
avg_price = df.groupby('Category')['Price'].mean().reset_index()

# Plotting the line graph
plt.figure(figsize=(10, 6))
plt.plot(avg_price['Category'], avg_price['Price'], marker='o', linestyle='-', color='b')
plt.xlabel('Product Name')
plt.ylabel('Average Price')
plt.title('Average Price by Product Name')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#BAR GRAPH
df.groupby('Category')['Sales'].sum().plot(kind='bar', color='c', figsize=(10, 6))
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.title('Total Sales by Product Name')
plt.grid(True)
plt.show()

# %%
# Histograms
plt.figure(figsize=(12, 6))

plt.subplot(2, 3, 1)
df['Price'].plot.hist(bins=10, edgecolor='black')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Price Distribution')

plt.subplot(2, 3, 2)
df['Rating'].plot.hist(bins=5, edgecolor='black')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Rating Distribution')

plt.subplot(2, 3, 3)
df['NumReviews'].plot.hist(bins=10, edgecolor='black')
plt.xlabel('Number of Reviews')
plt.ylabel('Frequency')
plt.title('Number of Reviews Distribution')

plt.subplot(2, 3, 4)
df['StockQuantity'].plot.hist(bins=10, edgecolor='black')
plt.xlabel('Stock Quantity')
plt.ylabel('Frequency')
plt.title('Stock Quantity Distribution')

plt.subplot(2, 3, 5)
df['Sales'].plot.hist(bins=10, edgecolor='black')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.title('Sales Distribution')

plt.tight_layout()
plt.show()

# %%
# Density plots
plt.figure(figsize=(12, 6))

plt.subplot(2, 3, 1)
sns.kdeplot(df['Price'], shade=True)
plt.xlabel('Price')
plt.ylabel('Density')
plt.title('Price Density Plot')

plt.subplot(2, 3, 2)
sns.kdeplot(df['Rating'], shade=True)
plt.xlabel('Rating')
plt.ylabel('Density')
plt.title('Rating Density Plot')

plt.subplot(2, 3, 3)
sns.kdeplot(df['NumReviews'], shade=True)
plt.xlabel('Number of Reviews')
plt.ylabel('Density')
plt.title('Number of Reviews Density Plot')

plt.subplot(2, 3, 4)
sns.kdeplot(df['StockQuantity'], shade=True)
plt.xlabel('Stock Quantity')
plt.ylabel('Density')
plt.title('Stock Quantity Density Plot')

plt.subplot(2, 3, 5)
sns.kdeplot(df['Sales'], shade=True)
plt.xlabel('Sales')
plt.ylabel('Density')
plt.title('Sales Density Plot')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_23472\2580320898.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Price'], shade=True)
# C:\Users\pavan\AppData\Local\Temp\ipykernel_23472\2580320898.py:11: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Rating'], shade=True)
# C:\Users\pavan\AppData\Local\Temp\ipykernel_23472\2580320898.py:17: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['NumReviews'], shade=True)
# C:\Users\pavan\AppData\Local\Temp\ipykernel_23472\2580320898.py:23: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# ...

# %%
# Scatter plots
plt.figure(figsize=(12, 6))

plt.subplot(2, 2, 1)
plt.scatter(df['Price'], df['Sales'])
plt.xlabel('Price')
plt.ylabel('Sales')
plt.title('Price vs Sales')

plt.subplot(2, 2, 2)
plt.scatter(df['Rating'], df['NumReviews'])
plt.xlabel('Rating')
plt.ylabel('Number of Reviews')
plt.title('Rating vs Number of Reviews')

plt.subplot(2, 2, 3)
plt.scatter(df['StockQuantity'], df['Sales'])
plt.xlabel('Stock Quantity')
plt.ylabel('Sales')
plt.title('Stock Quantity vs Sales')

plt.tight_layout()
plt.show()

# %%
# Correlation matrix
plt.figure(figsize=(8, 6))
correlation_matrix = df[['Price', 'Rating', 'NumReviews', 'StockQuantity', 'Sales']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %%
# Pair plot
sns.pairplot(df[['Price', 'Rating', 'NumReviews', 'StockQuantity', 'Sales']])
plt.suptitle('Pair Plot', y=1.02)
plt.show()

# %%
#Detailed Analysis:

#Analyze individual variables: Look at distributions, outliers, and transformations needed.
#Analyze relationships between variables: Use cross-tabulations, correlation analysis, and pivot tables

# %%
# Distributions
plt.subplot(3, 2, 1)
sns.histplot(df['Price'], bins=10, kde=True)
plt.title('Price Distribution')

plt.subplot(3, 2, 2)
sns.histplot(df['Rating'], bins=5, kde=True)
plt.title('Rating Distribution')

plt.subplot(3, 2, 3)
sns.histplot(df['NumReviews'], bins=10, kde=True)
plt.title('Number of Reviews Distribution')

plt.subplot(3, 2, 4)
sns.histplot(df['StockQuantity'], bins=10, kde=True)
plt.title('Stock Quantity Distribution')

plt.subplot(3, 2, 5)
sns.histplot(df['Sales'], bins=10, kde=True)
plt.title('Sales Distribution')

plt.tight_layout()
plt.show()

# %%
# Random sample or first 10 rows from the DataFrame
df = pd.DataFrame({
    'ProductID': np.arange(1000, 1010),
    'ProductName': ['Throw Blanket', 'Fleece Blanket', 'Throw Blanket', 'Weighted Blanket', 'Throw Blanket',
                     'Fleece Blanket', 'Weighted Blanket', 'Throw Blanket', 'Fleece Blanket', 'Weighted Blanket'],
    'Category': ['Blankets', 'Blankets', 'Blankets', 'Blankets', 'Blankets',
                 'Blankets', 'Blankets', 'Blankets', 'Blankets', 'Blankets'],
    'Price': np.random.uniform(50, 300, 10),
    'Rating': np.random.uniform(1, 5, 10),
    'NumReviews': np.random.randint(500, 5000, 10),
    'StockQuantity': np.random.randint(100, 1000, 10),
    'Discount': np.random.uniform(0.01, 0.5, 10),
    'Sales': np.random.randint(500, 2000, 10),
    'DateAdded': pd.date_range(start='2023-01-01', periods=10)
})

# Calculate averages
avg_price = df.groupby('ProductName')['Price'].mean()
avg_num_reviews = df.groupby('ProductName')['NumReviews'].mean()
avg_sales = df.groupby('ProductName')['Sales'].mean()

# Outliers Plot
plt.figure(figsize=(14, 6))

plt.subplot(1, 3, 1)
sns.boxplot(x=df['ProductName'], y=df['Price'])
plt.scatter(avg_price.index, avg_price.values, color='black', label='Average', marker='x', s=100)
plt.xlabel('Product Name')
plt.ylabel('Price')
plt.title('Price by Product Name')

plt.subplot(1, 3, 2)
sns.boxplot(x=df['ProductName'], y=df['NumReviews'])
plt.scatter(avg_num_reviews.index, avg_num_reviews.values, color='black', label='Average', marker='x', s=100)
plt.xlabel('Product Name')
plt.ylabel('Number of Reviews')
plt.title('Number of Reviews by Product Name')

plt.subplot(1, 3, 3)
sns.boxplot(x=df['ProductName'], y=df['Sales'])
plt.scatter(avg_sales.index, avg_sales.values, color='black', label='Average', marker='x', s=100)
plt.xlabel('Product Name')
plt.ylabel('Sales')
plt.title('Sales by Product Name')

plt.tight_layout()
plt.show()

# %%
# Transformations (log transformation example)
df['Log_NumReviews'] = df['NumReviews'].apply(lambda x: np.log(x + 1))  # Log transform with handling zeros

plt.figure(figsize=(8, 6))
sns.histplot(df['Log_NumReviews'], bins=10, kde=True)
plt.title('Log Transformed Number of Reviews Distribution')
plt.xlabel('Log(Number of Reviews)')
plt.ylabel('Frequency')
plt.show()

# %%
# Analyze relationships between variables
# Cross-tabulations
cross_tab = pd.crosstab(df['ProductName'], df['Category'])
print('Cross-tabulation - Product Name vs Category:\n', cross_tab)

# Correlation analysis
correlation_matrix = df[['Price', 'Rating', 'NumReviews', 'StockQuantity', 'Sales']].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# Pivot tables
pivot_table_sales = df.pivot_table(index='ProductName', values='Sales', aggfunc='mean')
print('Pivot Table - Mean Sales by Product Name:\n', pivot_table_sales)
# Out:
# Cross-tabulation - Product Name vs Category:
#  Category          Blankets
# ProductName
# Fleece Blanket           3
# Throw Blanket            4
# Weighted Blanket         3
# Pivot Table - Mean Sales by Product Name:
#                          Sales
# ProductName
# Fleece Blanket     927.000000
# Throw Blanket     1157.500000
# Weighted Blanket  1206.333333

# %%
#Identifying Patterns and Anomalies:

#Using clustering techniques and anomaly detection methods to identify unusual patterns.
#Performing time series analysis if applicable.

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
# Select numeric columns for clustering
numeric_cols = ['Price', 'Rating', 'NumReviews', 'StockQuantity', 'Discount', 'Sales']

# Standardize the data
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df[numeric_cols])

# Apply K-means clustering
kmeans = KMeans(n_clusters=3, random_state=42)
df['Cluster'] = kmeans.fit_predict(df_scaled)

# Plotting clusters
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Price', y='Sales', hue='Cluster', data=df, palette='Set1', s=100, alpha=0.8)
plt.title('Clusters of Products by Price and Sales')
plt.xlabel('Price')
plt.ylabel('Sales')
plt.legend(title='Cluster')
plt.show()

# %%
#Anomaly Detection
#We'll use Isolation Forest, an algorithm suitable for anomaly detection, to identify products that significantly differ from normal observations.

# %%
from sklearn.ensemble import IsolationForest

# Apply Isolation Forest for anomaly detection
isolation_forest = IsolationForest(contamination=0.1, random_state=42)
df['Anomaly'] = isolation_forest.fit_predict(df_scaled)

# Plotting anomalies
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Price', y='Sales', hue='Anomaly', data=df, palette='coolwarm', s=100, alpha=0.8)
plt.title('Anomalies in Products by Price and Sales')
plt.xlabel('Price')
plt.ylabel('Sales')
plt.legend(title='Anomaly', loc='upper right')
plt.show()

# Print anomalies
anomalies = df[df['Anomaly'] == -1]
print("Anomalous Products:")
print(anomalies[['ProductID', 'ProductName', 'Price', 'Sales']])
# Out:
# Anomalous Products:
#    ProductID     ProductName      Price  Sales
# 5       1005  Fleece Blanket  70.120383   1253

# %%
#Visualization:

#Create visualizations to illustrate key findings using libraries like Matplotlib, Seaborn, or Plotly.
#Use bar charts, line graphs, heatmaps, and pair plots to convey insights effectively.

# %%
# Pair Plot
sns.pairplot(df[['Price', 'Rating', 'NumReviews', 'Sales']], diag_kind='kde', plot_kws={'alpha': 0.6, 's': 50})
plt.suptitle('Pair Plot of Numeric Variables', y=1.02)
plt.tight_layout()
plt.show()

# %%
# Convert DateAdded to datetime
df['DateAdded'] = pd.to_datetime(df['DateAdded'])

# Trend of Sales Over Time
sales_over_time = df.groupby('DateAdded')['Sales'].sum()

plt.figure(figsize=(12, 6))
plt.plot(sales_over_time.index, sales_over_time.values, marker='o', linestyle='-', color='b')
plt.xlabel('Date Added')
plt.ylabel('Sales')
plt.title('Trend of Sales Over Time')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#Summary and Insights:

#Summarize your findings in a clear and concise manner.
#Highlight key patterns, correlations, and potential data issues.
#Provide actionable insights based on the analysis.

# %%
# Actionable Insights
# Marketing Strategy

# Focus marketing efforts on products in the Blankets category, which have shown higher average sales.
# Implement targeted marketing campaigns to promote higher-priced items, which have demonstrated higher sales potential.
# Product Development

# Encourage customers to leave reviews to improve data accuracy and provide deeper insights into product performance and customer preferences.
# Monitor trends in sales over time to optimize inventory and marketing strategies based on seasonal variations and customer demand.
# Sales Strategy

# Adjust pricing strategies for products to maximize sales potential, considering the positive correlation between Price and Sales.
# Utilize insights from customer reviews and ratings to enhance product offerings and customer satisfaction.
# Conclusion
# This analysis provides valuable insights into the performance of different product categories, pricing strategies, and customer feedback. 
#By leveraging these insights, businesses can refine their marketing, sales, and product development strategies to improve overall performance and customer satisfaction.
#Continuous monitoring and adaptation based on new data will be essential to maintaining competitiveness in the market.
